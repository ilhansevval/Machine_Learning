# %%
from operator import truediv
import math
import random

x=int(input("Choose your door:"))
def std1(door):
    y=int(0)
    st1=float(0)
    doors=[]
    values=["Goat","Goat","Car"]
    doors=values
    
    for i in range(0, 1000):
        doors=random.sample(doors,3)
        print(doors)
        door_open=None
        
        if doors[x]!="Car":
          door_open=False
        else:
          door_open=True
          y+=1
        pass
    st1=(y/10)
    print("Probability of your success: %" +str(st1))
        
def std2(door):
    y=int(0)
    st2=float(0)
    doors=[]
    values=["Goat","Goat","Car"]
    doors=values
    
    for i in range(0, 1000):
        doors=random.sample(doors,3)
        print(doors)
        door_open=None
        
        if doors[x]=="Car":
            door_open=False
        elif doors[x]=="Goat":
            door_open=True
            y+=1
        pass  
    st2=(y/10)
    print("Probability of your success: %" +str(st2))      
                        
std2(x)
# Out:
# Choose your door:1
# ['Goat', 'Goat', 'Car']
# ['Goat', 'Goat', 'Car']
# ['Car', 'Goat', 'Goat']
# ['Car', 'Goat', 'Goat']
# ['Goat', 'Goat', 'Car']
# ['Goat', 'Goat', 'Car']
# ['Car', 'Goat', 'Goat']
# ['Car', 'Goat', 'Goat']
# ['Goat', 'Car', 'Goat']
# ['Car', 'Goat', 'Goat']
# ['Goat', 'Car', 'Goat']
# ['Goat', 'Goat', 'Car']
# ['Goat', 'Goat', 'Car']
# ['Car', 'Goat', 'Goat']
# ['Goat', 'Goat', 'Car']
# ['Car', 'Goat', 'Goat']
# ['Goat', 'Goat', 'Car']
# ['Goat', 'Car', 'Goat']
# ['Car', 'Goat', 'Goat']
# ['Car', 'Goat', 'Goat']
# ['Goat', 'Car', 'Goat']
# ['Goat', 'Goat', 'Car']
# ['Goat', 'Goat', 'Car']
# ['Car', 'Goat', 'Goat']
# ['Goat', 'Car', 'Goat']
# ['Goat', 'Car', 'Goat']
# ['Goat', 'Goat', 'Car']
# ['Car', 'Goat', 'Goat']
# ['Goat', 'Car', 'Goat']
# ['Goat', 'Goat', 'Car']
# ['Car', 'Goat', 'Goat']
# ['Car', 'Goat', 'Goat']
# ['Goat', 'Goat', 'Car']
# ['Goat', 'Car', 'Goat']
# ['Goat', 'Car', 'Goat']
# ['Car', 'Goat', 'Goat']
# ['Goat', 'Car', 'Goat']
# ...
